# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# importing dataset

df = pd.read_csv("Dataset/Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1 = df.copy()

# %%
df2 = df
df3 = df

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# Simple Operations

(df["Age"]+1).head()
# Out:
# 0    35.5
# 1    48.0
# 2    63.0
# 3    28.0
# 4    23.0
# Name: Age, dtype: float64

# %% [markdown]
# # Dealing with Missing Values
#
# Replacing Missing Values
#
# 1. Average value of entire variable or similar data point
# 2. Frequency or MODE replacement
# 3. Replace based on other functions (Data sampler knows that)
# 4. ML algorithm can also be used.
# 5. Leave it like that

# %% [markdown]
# ### Dropping missing values using "dropna()" method

# %%
# Where exactly missing values are?

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.shape
# Out:
# (418, 12)

# %%
# use dropna method to drop values

df.dropna(subset=["Age"], axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          245
# Embarked         0
# dtype: int64

# %%
df.dropna(subset=["Cabin"], axis=0, inplace=True)

# %%
df.shape
# Out:
# (87, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Dropping missing values from whole dataset

df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df1.shape
# Out:
# (87, 12)

# %%
df1.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                       Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
#
#     Parch       Ticket      Fare            Cabin Embarked
# 12      0        21228   82.2667              B45        S
# 14      0  W.E.P. 5734   61.1750              E31        S
# 24      3     PC 17608  262.3750  B57 B59 B63 B66        C
# 26      1       113509   61.9792              B36        C
# ...

# %% [markdown]
# ### Replacing Missing values with the average of that column

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df2.shape
# Out:
# (418, 12)

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Finding an average (mean)

Age_mean = df2["Age"].mean()
Age_mean
# Out:
# 30.272590361445783

# %%
df2["Age"] = df2["Age"].replace(np.nan, Age_mean)

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Assignment

# %%
df2["Fare"].isnull().sum()
# Out:
# 1

# %%
# Finding an average (mean) of the column "Fare"

Fare_mean = df2["Fare"].mean()
Fare_mean
# Out:
# 35.6271884892086

# %%
# Replacing NaN values from mean of the column "Fare"

df2["Fare"] = df2["Fare"].replace(np.nan, Fare_mean)

# %%
df2["Fare"].isnull().sum()
# Out:
# 0

# %%
# Removing NaN value from "Cabin" column of titanic dataset

df2.dropna(subset=["Cabin"], axis=0, inplace=True)

# %%
df2["Cabin"].isnull().sum()    # the NaN has been removed
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Finding an average (mean) of the column "Age"

Age_mean = df2["Fare"].mean()
Age_mean
# Out:
# 94.9031615384615

# %%
# Replacing NaN values from mean of the column "Age"

df2["Age"] = df2["Age"].replace(np.nan, Age_mean)

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### Data Formatting

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Know the data type and convert it into the known one

df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# use this method to convert datatype from one to another format

df["Survived"] = df["Survived"].astype("float64")

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Here we'll convert the age into days instead of years

df["Age"] = df["Age"]*365
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904       1.0       1
# 14          906       1.0       1
# 24          916       1.0       1
# 26          918       1.0       1
# 28          920       0.0       1
#
#                                                  Name     Sex        Age  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  3064175.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  6261575.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  6394800.0
# 26                       Ostby, Miss. Helene Ragnhild  female  2930950.0
# 28                            Brady, Mr. John Bertram    male  5462225.0
#
#     SibSp  Parch       Ticket      Fare            Cabin Embarked
# 12      1      0        21228   82.2667              B45        S
# 14      1      0  W.E.P. 5734   61.1750              E31        S
# 24      1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...

# %%
# Rename the Age column

df.rename( columns={"Age" : "Age in days"}, inplace=True)
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904       1.0       1
# 14          906       1.0       1
# 24          916       1.0       1
# 26          918       1.0       1
# 28          920       0.0       1
#
#                                                  Name     Sex  Age in days  \
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female    3064175.0
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female    6261575.0
# 24    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female    6394800.0
# 26                       Ostby, Miss. Helene Ragnhild  female    2930950.0
# 28                            Brady, Mr. John Bertram    male    5462225.0
#
#     SibSp  Parch       Ticket      Fare            Cabin Embarked
# 12      1      0        21228   82.2667              B45        S
# 14      1      0  W.E.P. 5734   61.1750              E31        S
# 24      1      3     PC 17608  262.3750  B57 B59 B63 B66        C
# ...
